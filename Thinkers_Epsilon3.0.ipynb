# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel("Epsilon.xlsx",sheet_name = "Data")
df
# Out:
#                                     Loan ID  Loan Number  New Credit Customer  \
# 0      87227056-6BF9-410C-98D1-008F788E122A       349381                 True
# 1      2DDE6336-E466-4624-A337-00A0ED1A1468       443082                 True
# 2      BA1FC89D-44B5-4481-9FCD-00C4BBC174B0       430905                 True
# 3      932B0F92-8B44-499F-A056-00C6D6D1E312       473276                 True
# 4      CDC5127D-AE6E-4BEC-9508-00FE1FB8FFE4       348441                 True
# ...                                     ...          ...                  ...
# 18002  7DB9654B-E768-4C7B-97DF-AD4700CFC204      2277120                False
# 18003  51CC154C-DDAE-47BE-ADE3-AD470111271A      2277407                 True
# 18004  C8865378-636D-46EA-96B9-AD470123B0F2      2277513                False
# 18005  7C7A9C9C-CFA6-47C7-AB36-AD470127D3C3      2277530                 True
# 18006  9BAC37DC-01B3-42D0-B664-AD47012A2887      2277539                 True
#
# ...

# %%
df.describe()
# Out:
#         Loan Number  Application Signed Hour           Age  Applied Amount  \
# count  1.800700e+04             18007.000000  18007.000000    18007.000000
# mean   6.376259e+05                13.733826     39.099406     3045.509891
# std    4.899150e+05                 4.621094     11.726468     2508.816833
# min    1.587900e+04                 0.000000     18.000000      139.900000
# 25%    3.675390e+05                11.000000     30.000000     1060.000000
# 50%    5.189380e+05                14.000000     38.000000     2200.000000
# 75%    6.358815e+05                17.000000     47.000000     4150.000000
# max    2.277539e+06                23.000000     71.000000    10632.000000
#
#              Amount      Interest  Loan Duration  Monthly Payment  \
# count  18007.000000  18007.000000   18007.000000     18007.000000
# mean    2672.480569     34.426073      46.330982       125.472556
# std     2155.283563     23.827371      16.403067       136.609617
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18007 entries, 0 to 18006
# Data columns (total 39 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Loan ID                             18007 non-null  object
#  1   Loan Number                         18007 non-null  int64
#  2   New Credit Customer                 18007 non-null  bool
#  3   Loan Application Started Date       18007 non-null  object
#  4   Loan Date                           18007 non-null  object
#  5   First Payment Date                  18007 non-null  object
#  6   Maturity Date Original              18007 non-null  object
#  7   Maturity Date Last                  18007 non-null  object
#  8   Application Signed Hour             18007 non-null  int64
#  9   Application Signed Weekday          18007 non-null  object
#  10  Verification Type                   18007 non-null  object
# ...

# %% [markdown]
# ### Checking for the missing values

# %%
df.isna().sum()
# Out:
# Loan ID                                  0
# Loan Number                              0
# New Credit Customer                      0
# Loan Application Started Date            0
# Loan Date                                0
# First Payment Date                       0
# Maturity Date Original                   0
# Maturity Date Last                       0
# Application Signed Hour                  0
# Application Signed Weekday               0
# Verification Type                        0
# Age                                      0
# Gender                                   0
# Country                                  0
# Applied Amount                           0
# Amount                                   0
# Interest                                 0
# Loan Duration                            0
# Monthly Payment                          0
# Use Of Loan                              0
# Education                                0
# No. Of Dependants                     3773
# ...

# %% [markdown]
# ### Checking for duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### So, there are no duplicates in our dataset.

# %%
df.nunique()
# Out:
# Loan ID                               18007
# Loan Number                           18007
# New Credit Customer                       2
# Loan Application Started Date         17896
# Loan Date                              2552
# First Payment Date                     1504
# Maturity Date Original                 2037
# Maturity Date Last                     2319
# Application Signed Hour                  24
# Application Signed Weekday                7
# Verification Type                         4
# Age                                      54
# Gender                                    2
# Country                                   4
# Applied Amount                          350
# Amount                                 1528
# Interest                               3803
# Loan Duration                            12
# Monthly Payment                       10367
# Use Of Loan                               9
# Education                                 5
# ...

# %% [markdown]
# ### Dealing with missing values

# %%
df['No. Of Dependants'] = df['No. Of Dependants'].fillna('No record found')
df['Work Experience'] = df['Work Experience'].fillna('No record found')
df['Principal Write Offs'] = df['Principal Write Offs'].fillna('No record found')
df['Interest And Penalty Write Offs'] = df['Interest And Penalty Write Offs'].fillna('No record found')

# %%
df
# Out:
#                                     Loan ID  Loan Number  New Credit Customer  \
# 0      87227056-6BF9-410C-98D1-008F788E122A       349381                 True
# 1      2DDE6336-E466-4624-A337-00A0ED1A1468       443082                 True
# 2      BA1FC89D-44B5-4481-9FCD-00C4BBC174B0       430905                 True
# 3      932B0F92-8B44-499F-A056-00C6D6D1E312       473276                 True
# 4      CDC5127D-AE6E-4BEC-9508-00FE1FB8FFE4       348441                 True
# ...                                     ...          ...                  ...
# 18002  7DB9654B-E768-4C7B-97DF-AD4700CFC204      2277120                False
# 18003  51CC154C-DDAE-47BE-ADE3-AD470111271A      2277407                 True
# 18004  C8865378-636D-46EA-96B9-AD470123B0F2      2277513                False
# 18005  7C7A9C9C-CFA6-47C7-AB36-AD470127D3C3      2277530                 True
# 18006  9BAC37DC-01B3-42D0-B664-AD47012A2887      2277539                 True
#
# ...

# %%
df.isna().sum()
# Out:
# Loan ID                               0
# Loan Number                           0
# New Credit Customer                   0
# Loan Application Started Date         0
# Loan Date                             0
# First Payment Date                    0
# Maturity Date Original                0
# Maturity Date Last                    0
# Application Signed Hour               0
# Application Signed Weekday            0
# Verification Type                     0
# Age                                   0
# Gender                                0
# Country                               0
# Applied Amount                        0
# Amount                                0
# Interest                              0
# Loan Duration                         0
# Monthly Payment                       0
# Use Of Loan                           0
# Education                             0
# No. Of Dependants                     0
# Work Experience                       0
# ...

# %% [markdown]
# ### Dropping the redundant columns which we don't need for our analysis

# %%
df.drop('Loan ID',axis = 1,inplace=True)

# %%
df.drop('Application Signed Hour',axis=1,inplace=True)

# %%
df.drop('Application Signed Weekday',axis=1,inplace=True)

# %%
df
# Out:
#        Loan Number  New Credit Customer Loan Application Started Date  \
# 0           349381                 True              20-03-2015 15:20
# 1           443082                 True              13-12-2015 00:30
# 2           430905                 True              12-11-2015 12:58
# 3           473276                 True              29-02-2016 10:25
# 4           348441                 True              17-03-2015 08:25
# ...            ...                  ...                           ...
# 18002      2277120                False              14-06-2021 12:36
# 18003      2277407                 True              14-06-2021 16:34
# 18004      2277513                False              14-06-2021 17:42
# 18005      2277530                 True              14-06-2021 17:57
# 18006      2277539                 True              14-06-2021 18:05
#
#         Loan Date First Payment Date Maturity Date Original  \
# 0      27-03-2015         04-05-2015             01-04-2020
# ...

# %% [markdown]
# ### Extracting the year from Loan Application started date column

# %%
df['Loan Application Started Date'] = pd.DatetimeIndex(df['Loan Application Started Date']).date
df['Loan Application Started Date'].head()
# Out:
# 0    2015-03-20
# 1    2015-12-13
# 2    2015-12-11
# 3    2016-02-29
# 4    2015-03-17
# Name: Loan Application Started Date, dtype: object

# %%
df
# Out:
#        Loan Number  New Credit Customer Loan Application Started Date  \
# 0           349381                 True                    2015-03-20
# 1           443082                 True                    2015-12-13
# 2           430905                 True                    2015-12-11
# 3           473276                 True                    2016-02-29
# 4           348441                 True                    2015-03-17
# ...            ...                  ...                           ...
# 18002      2277120                False                    2021-06-14
# 18003      2277407                 True                    2021-06-14
# 18004      2277513                False                    2021-06-14
# 18005      2277530                 True                    2021-06-14
# 18006      2277539                 True                    2021-06-14
#
#         Loan Date First Payment Date Maturity Date Original  \
# 0      27-03-2015         04-05-2015             01-04-2020
# ...

# %% [markdown]
# ### Discretization of Age column

# %%
df['Age'].min()
# Out:
# 18

# %%
df['Age'].max()
# Out:
# 71

# %%
binning.codes
# Out:
# array([1, 0, 0, ..., 0, 1, 1], dtype=int8)

# %%
binning.categories
# Out:
# IntervalIndex([(17, 40], (40, 60], (60, 75]], dtype='interval[int64, right]')

# %%
pd.value_counts(binning)
# Out:
# (17, 40]    10538
# (40, 60]     6494
# (60, 75]      975
# dtype: int64

# %%
group_names = ['Adult','Middle age adult','Senior citizen']
pd.cut(Age,bins,labels=group_names)
# Out:
# ['Middle age adult', 'Adult', 'Adult', 'Adult', 'Middle age adult', ..., 'Adult', 'Adult', 'Adult', 'Middle age adult', 'Middle age adult']
# Length: 18007
# Categories (3, object): ['Adult' < 'Middle age adult' < 'Senior citizen']

# %%
df['Age group'] = pd.cut(df['Age'],bins,labels = group_names)
df.head()
# Out:
#    Loan Number  New Credit Customer Loan Application Started Date   Loan Date  \
# 0       349381                 True                    2015-03-20  27-03-2015
# 1       443082                 True                    2015-12-13  22-12-2015
# 2       430905                 True                    2015-12-11  19-11-2015
# 3       473276                 True                    2016-02-29  29-02-2016
# 4       348441                 True                    2015-03-17  01-04-2015
#
#   First Payment Date Maturity Date Original Maturity Date Last  \
# 0         04-05-2015             01-04-2020         01-04-2020
# 1         01-02-2016             02-01-2020         02-01-2020
# 2         04-01-2016             01-12-2020         01-12-2020
# 3         15-04-2016             15-03-2021         12-06-2019
# 4         25-05-2015             25-04-2016         25-04-2016
#
#   Verification Type  Age  Gender  ... Restructured  Principal Payments Made  \
# ...

# %%
df.drop('Age',axis=1,inplace=True)

# %%
df
# Out:
#        Loan Number  New Credit Customer Loan Application Started Date  \
# 0           349381                 True                    2015-03-20
# 1           443082                 True                    2015-12-13
# 2           430905                 True                    2015-12-11
# 3           473276                 True                    2016-02-29
# 4           348441                 True                    2015-03-17
# ...            ...                  ...                           ...
# 18002      2277120                False                    2021-06-14
# 18003      2277407                 True                    2021-06-14
# 18004      2277513                False                    2021-06-14
# 18005      2277530                 True                    2021-06-14
# 18006      2277539                 True                    2021-06-14
#
#         Loan Date First Payment Date Maturity Date Original  \
# 0      27-03-2015         04-05-2015             01-04-2020
# ...

# %%
df.columns
# Out:
# Index(['Loan Number', 'New Credit Customer', 'Loan Application Started Date',
#        'Loan Date', 'First Payment Date', 'Maturity Date Original',
#        'Maturity Date Last', 'Verification Type', 'Gender', 'Country',
#        'Applied Amount', 'Amount', 'Interest', 'Loan Duration',
#        'Monthly Payment', 'Use Of Loan', 'Education', 'No. Of Dependants',
#        'Work Experience', 'Income From Principal Employer',
#        'Income From Pension', 'Income Other', 'Liabilities Total',
#        'Last Payment On', 'Probability Of Default', 'Status', 'Restructured',
#        'Principal Payments Made', 'Interest And Penalty Payments Made',
#        'Principal Write Offs', 'Interest And Penalty Write Offs',
#        'Principal Balance', 'Interest And Penalty Balance',
#        'No. Of Previous Loans Before Loan', 'Rating', 'Age group'],
#       dtype='object')

# %% [markdown]
# ### Discretization of Probability of default column

# %%
df['Probability Of Default'] = df['Probability Of Default'] * 100
df['Probability Of Default']
# Out:
# 0        18.872625
# 1        74.951122
# 2        45.318175
# 3        40.803591
# 4        45.318175
#            ...
# 18002    16.700000
# 18003    12.424000
# 18004     9.090000
# 18005    12.424000
# 18006    12.424000
# Name: Probability Of Default, Length: 18007, dtype: float64

# %%
df['Probability Of Default'].min()
# Out:
# 0.134

# %%
df['Probability Of Default'].max()
# Out:
# 95.0478287

# %%
df.rename(columns={'Probability Of Default':'Percentage_defaulting'},inplace=True)
df
# Out:
#        Loan Number  New Credit Customer Loan Application Started Date  \
# 0           349381                 True                    2015-03-20
# 1           443082                 True                    2015-12-13
# 2           430905                 True                    2015-12-11
# 3           473276                 True                    2016-02-29
# 4           348441                 True                    2015-03-17
# ...            ...                  ...                           ...
# 18002      2277120                False                    2021-06-14
# 18003      2277407                 True                    2021-06-14
# 18004      2277513                False                    2021-06-14
# 18005      2277530                 True                    2021-06-14
# 18006      2277539                 True                    2021-06-14
#
#         Loan Date First Payment Date Maturity Date Original  \
# 0      27-03-2015         04-05-2015             01-04-2020
# ...

# %%
df.columns
# Out:
# Index(['Loan Number', 'New Credit Customer', 'Loan Application Started Date',
#        'Loan Date', 'First Payment Date', 'Maturity Date Original',
#        'Maturity Date Last', 'Verification Type', 'Gender', 'Country',
#        'Applied Amount', 'Amount', 'Interest', 'Loan Duration',
#        'Monthly Payment', 'Use Of Loan', 'Education', 'No. Of Dependants',
#        'Work Experience', 'Income From Principal Employer',
#        'Income From Pension', 'Income Other', 'Liabilities Total',
#        'Last Payment On', 'Percentage_defaulting', 'Status', 'Restructured',
#        'Principal Payments Made', 'Interest And Penalty Payments Made',
#        'Principal Write Offs', 'Interest And Penalty Write Offs',
#        'Principal Balance', 'Interest And Penalty Balance',
#        'No. Of Previous Loans Before Loan', 'Rating', 'Age group'],
#       dtype='object')

# %%
bins = [0,20,60,100]
Percentage_defaulting = list(df['Percentage_defaulting'])
binning = pd.cut(Percentage_defaulting,bins)
binning
# Out:
# [(0, 20], (60, 100], (20, 60], (20, 60], (20, 60], ..., (0, 20], (0, 20], (0, 20], (0, 20], (0, 20]]
# Length: 18007
# Categories (3, interval[int64, right]): [(0, 20] < (20, 60] < (60, 100]]

# %%
binning.codes
# Out:
# array([0, 2, 1, ..., 0, 0, 0], dtype=int8)

# %%
binning.categories
# Out:
# IntervalIndex([(0, 20], (20, 60], (60, 100]], dtype='interval[int64, right]')

# %%
pd.value_counts(binning)
# Out:
# (0, 20]      9959
# (20, 60]     7232
# (60, 100]     816
# dtype: int64

# %%
group_names = ['Low probability','Moderate probability','High probability']
pd.cut(Percentage_defaulting,bins,labels=group_names)
# Out:
# ['Low probability', 'High probability', 'Moderate probability', 'Moderate probability', 'Moderate probability', ..., 'Low probability', 'Low probability', 'Low probability', 'Low probability', 'Low probability']
# Length: 18007
# Categories (3, object): ['Low probability' < 'Moderate probability' < 'High probability']

# %%
df['Defaulting_on_loan'] = pd.cut(df['Percentage_defaulting'],bins,labels = group_names)
df.head()
# Out:
#    Loan Number  New Credit Customer Loan Application Started Date   Loan Date  \
# 0       349381                 True                    2015-03-20  27-03-2015
# 1       443082                 True                    2015-12-13  22-12-2015
# 2       430905                 True                    2015-12-11  19-11-2015
# 3       473276                 True                    2016-02-29  29-02-2016
# 4       348441                 True                    2015-03-17  01-04-2015
#
#   First Payment Date Maturity Date Original Maturity Date Last  \
# 0         04-05-2015             01-04-2020         01-04-2020
# 1         01-02-2016             02-01-2020         02-01-2020
# 2         04-01-2016             01-12-2020         01-12-2020
# 3         15-04-2016             15-03-2021         12-06-2019
# 4         25-05-2015             25-04-2016         25-04-2016
#
#   Verification Type  Gender        Country  ...  Principal Payments Made  \
# ...

# %%
df
# Out:
#        Loan Number  New Credit Customer Loan Application Started Date  \
# 0           349381                 True                    2015-03-20
# 1           443082                 True                    2015-12-13
# 2           430905                 True                    2015-12-11
# 3           473276                 True                    2016-02-29
# 4           348441                 True                    2015-03-17
# ...            ...                  ...                           ...
# 18002      2277120                False                    2021-06-14
# 18003      2277407                 True                    2021-06-14
# 18004      2277513                False                    2021-06-14
# 18005      2277530                 True                    2021-06-14
# 18006      2277539                 True                    2021-06-14
#
#         Loan Date First Payment Date Maturity Date Original  \
# 0      27-03-2015         04-05-2015             01-04-2020
# ...

# %% [markdown]
# ### Exporting the data to Excel

# %%
df.to_excel('Epsilon.xlsx',sheet_name = 'New_Data',index=False)
